# %%
print('los seeker')
# %run examples/los_seeker.ipynb


print('pn')
# %run examples/proportional_navigation.ipynb


print('radar')
# %run examples/radar.ipynb


print('free fall')
# %run examples/freefall.ipynb


print('detect track')
# %run examples/detect_track.ipynb


print('dof6 sim')
# %run examples/dof6sim.ipynb


print('pendulum')
# %run examples/double_pendulum.ipynb
# Out:
# los seeker
# pn
# radar
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# free fall
# detect track
# 0.00s: new track: 0
# ['truck', 'person']
# 0.03s: new track: 1
# ['truck', 'person']
# ['truck', 'person']
# ['truck']
# ['truck']
# ['person']
# ['person', 'horse']
# ['person', 'horse']
# 0.27s: new track: 2
# 0.27s: new track: 3
# ['person', 'truck', 'truck']
# ['person']
# []
# {t:.2f}: closing duplicated trk 1
# ['truck']
# {t:.2f}: closing duplicated trk 3
# ['train']
# ['train']
# []
# ['truck']
# []
# ['truck']
# ['truck']
# ['truck']
# []
# []
# []
# []
# []
# []
# ['truck']
# ['truck']
# ['truck']
# ['truck']
# 119.87157678604126
# video length: 1
# number of detected objects: 4
# process time:2.0min
# dof6 sim
# tauseeker: 2.850, tauctrl: 3.359, miss: 13.18353, flight time: 10.0
# tauseeker: 0.876, tauctrl: 2.074, miss: 0.98882, flight time: 9.8
# tauseeker: 2.684, tauctrl: 1.640, miss: 12.15037, flight time: 10.0
# tauseeker: 3.407, tauctrl: 1.951, miss: 13.00116, flight time: 10.1
# tauseeker: 0.757, tauctrl: 0.528, miss: 0.85295, flight time: 9.8
# tauseeker: 3.111, tauctrl: 1.552, miss: 13.84068, flight time: 10.0
# tauseeker: 3.343, tauctrl: 2.256, miss: 13.34592, flight time: 10.0
# tauseeker: 1.790, tauctrl: 1.863, miss: 3.14825, flight time: 9.9
# tauseeker: 1.182, tauctrl: 2.649, miss: 0.85516, flight time: 9.8
# tauseeker: 2.719, tauctrl: 0.957, miss: 12.40176, flight time: 10.0
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# 17.376798152923584
# pendulum
# warning: this example has nothing to do with c4d
# d:\gh_repo\C4dynamics\.venv\lib\site-packages\nbformat\__init__.py:93: MissingIDFieldWarning: Code cell is missing an id field, this will become a hard error in future nbformat versions. You may want to use `normalize()` on your notebooks before validations (available since nbformat 5.1.4). Previous versions of nbformat are fixing this issue transparently, and will stop doing so in the future.
#   validate(nb)
# initial conditions: [1.34639685 0.         2.35619449 0.        ]
# A subdirectory or file -p already exists.
# Error occurred while processing: -p.
# A subdirectory or file examples\out\pendulum already exists.
# Error occurred while processing: examples\out\pendulum.
# energy is fine
# images saved in examples\out\pendulum
