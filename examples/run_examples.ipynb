# %%
print('los seeker')
# %run examples/los_seeker.ipynb


print('pn')
# %run examples/proportional_navigation.ipynb


print('radar')
# %run examples/radar.ipynb


print('free fall')
# %run examples/freefall.ipynb


print('detect track')
# %run examples/detect_track.ipynb


print('dof6 sim')
# %run examples/dof6sim.ipynb


print('pendulum')
# %run examples/double_pendulum.ipynb
# Out:
# los seeker
# pn
# radar
# free fall
# detect track
# 0.00s: new track: 0
# ['truck', 'person']
# 0.03s: new track: 1
# ['truck', 'person']
# ['truck', 'person']
# ['truck']
# ['truck']
# ['person']
# ['person', 'horse']
# ['person', 'horse']
# 0.27s: new track: 2
# 0.27s: new track: 3
# ['person', 'truck', 'truck']
# ['person']
# []
# {t:.2f}: closing duplicated trk 1
# ['truck']
# {t:.2f}: closing duplicated trk 3
# ['train']
# ['train']
# []
# ['truck']
# []
# ['truck']
# ['truck']
# ['truck']
# []
# []
# []
# []
# []
# []
# ['truck']
# ['truck']
# ['truck']
# ['truck']
# 130.40243339538574
# video length: 1
# number of detected objects: 4
# process time:2.17min
# dof6 sim
# tauseeker: 2.421, tauctrl: 1.438, miss: 9.78364, flight time: 9.9
# tauseeker: 1.779, tauctrl: 2.015, miss: 3.06268, flight time: 9.9
# tauseeker: 2.116, tauctrl: 2.803, miss: 6.41517, flight time: 9.9
# tauseeker: 2.102, tauctrl: 2.085, miss: 6.26325, flight time: 9.9
# tauseeker: 2.288, tauctrl: 1.250, miss: 8.33160, flight time: 9.9
# tauseeker: 1.573, tauctrl: 2.767, miss: 1.72051, flight time: 9.8
# tauseeker: 2.372, tauctrl: 3.605, miss: 9.24428, flight time: 9.9
# tauseeker: 1.360, tauctrl: 1.651, miss: 1.00401, flight time: 9.8
# tauseeker: 3.224, tauctrl: 1.216, miss: 13.74184, flight time: 10.0
# tauseeker: 2.795, tauctrl: 4.081, miss: 12.87816, flight time: 10.0
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# 10.697862148284912
# pendulum
# d:\gh_repo\c4dynamics\.venv\lib\site-packages\nbformat\__init__.py:93: MissingIDFieldWarning: Code cell is missing an id field, this will become a hard error in future nbformat versions. You may want to use `normalize()` on your notebooks before validations (available since nbformat 5.1.4). Previous versions of nbformat are fixing this issue transparently, and will stop doing so in the future.
#   validate(nb)
# warning: this example has nothing to do with c4d
# initial conditions: [1.34639685 0.         2.35619449 0.        ]
# A subdirectory or file -p already exists.
# Error occurred while processing: -p.
# A subdirectory or file examples\out\pendulum already exists.
# Error occurred while processing: examples\out\pendulum.
# energy is fine
# images saved in examples\out\pendulum
