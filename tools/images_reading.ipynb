# %%
import images_loader
from importlib import reload  # Python 3.4+
from matplotlib import pyplot
reload(images_loader)

fol = '../'

imgs3s = images_loader.sngl3(fol + 'c4a.png')
imgsvs = images_loader.snglv(fol + 'c4a.png')
imgs3m = images_loader.mltpl3(fol + '*')
imgs3v = images_loader.mltplv(fol + '*')

# %%
print(imgs3s.dtype)
print(imgs3s.shape)
# display the array of pixels as an image
pyplot.imshow(imgs3s)
pyplot.show()
# Out:
# float32
# (138, 158, 3)

# %%
print(imgsvs[0].dtype)
print(imgsvs[0].shape)
# # display the array of pixels as an image
# pyplot.imshow(imgsvs[0])
# pyplot.show()
# Out:
# float32
# (65412,)

# %%
for im in imgs3m:
    print(im.dtype)
    print(im.shape)
    # display the array of pixels as an image
    pyplot.imshow(im)
    pyplot.show()
# Out:
# uint8
# (984, 638, 3)
# float32
# (138, 158, 3)
# float32
# (138, 158, 3)
# float32
# (139, 340, 4)

# %%
for img in imgs3v:
    print(img.dtype)
    print(img.shape)
# Out:
# uint8
# (1, 1883376)
# float32
# (1, 65412)
# float32
# (1, 65412)
# float32
# (1, 189040)
